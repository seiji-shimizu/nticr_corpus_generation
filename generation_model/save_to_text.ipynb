# %%
import os
import pickle

# %%
data_dir2 = 'generated_text2_filtered/'
data_dir1 = 'generated_text1_filtered/'

# %%
file_list2 = os.listdir(data_dir2)

# %%
data_dir2+file_list2[0]
# Out:
# 'generated_text2_filtered/造影剤generated_text2.pickle'

# %%
with open(data_dir2+file_list2[0],'rt') as f:
    text = f.read()

# %%
len(text.split('\n'))
# Out:
# 722

# %%
for file in os.listdir(data_dir2):
    with open(data_dir2+file,'rt') as f:
        text = f.read()
    filename = file.replace('pickle','')
    filename = filename.replace('generated_text2.','')
    print(filename)
    print(len(text.split('\n')))
    #with open('generated_text_with_beamsearch/'+filename,'w') as f:
        #f.write(text)
# Out:
# 造影剤
# 722
# メトホルミン
# 827
# グルカゴン
# 776
# ミノサイクリン
# 834
# ＳＴ合剤
# 793
# インフリキシマブ
# 782
# ヒドロコルチゾン
# 717
# デキサメサゾン
# 789
# インスリン
# 823
# 強化インスリン
# 805
# セフトリアキソン
# 839
# プレドニン
# 820
# シスプラチン
# 800
# タクロリムス
# 787
# デキサメタゾン
# 794
# メトロニダゾール
# 730
# アルブミン
# 846
# アザチオプリン
# 823
# コルチゾール
# 845
# ウロキナーゼ
# 763
# ステロイドパルス
# 779
# 抗結核薬
# 746
# トルバプタン
# 801
# メトトレキサート
# 798
# アルガトロバン
# 793
# インターフェロン
# 799
# メロペネム
# 726
# グリメピリド
# 808
# ガンシクロビル
# 713
# プレドニゾロン
# 802
# 利尿薬
# 878
# ステロイド
# 817
# イマチニブ
# 769
# コルヒチン
# 792
# カテコラミン
# 816
# 抗凝固薬
# 809
# 降圧薬
# 867
# ヘパリン
# 651
# 抗生剤
# 790
# シクロフォスファミド
# 794
# リツキシマブ
# 825
# 免疫抑制剤
# 792
# アミオダロン
# 791
# メチルプレドニゾロン
# 793
# 免疫グロブリン
# 725
# アルドステロン
# 827
# アシクロビル
# 802
# シクロホスファミド
# 782
# 補液
# 781
# 抗血小板薬
# 834
# ワーファリン
# 777
# 輸液
# 781
# 降圧剤
# 859
# ワルファリン
# 459
# 利尿剤
# 868
# リバビリン
# 753
# 抗菌薬
# 831
# フロセミド
# 829
# チアマゾール
# 774
# バンコマイシン
# 790
# メサラジン
# 826
# 抗生物質
# 779
# ノルアドレナリン
# 736
# 抗菌剤
# 820
# アスピリン
# 764
# シクロスポリン
# 760
# γグロブリン
# 762
# ステロイド剤
# ...

# %%
for file in os.listdir(data_dir1):
    with open(data_dir1+file,'rt') as f:
        text = f.read()
    filename = file.replace('pickle','')
    filename = filename.replace('generated_text1.','')
    print(filename)
    print(len(text.split('\n')))
    #with open('generated_text_with_beamsearch/'+filename,'w') as f:
        #f.write(text)
# Out:
# コルヒチンtxt
# 5433
# インターフェロンtxt
# 1664
# γグロブリンtxt
# 220
# ＳＴ合剤txt
# 7767
# ヘパリンtxt
# 4025
# 補液txt
# 5132
# ワルファリンtxt
# 2007
# インフリキシマブtxt
# 5271
# 強化インスリンtxt
# 5093
# 免疫抑制剤txt
# 7057
# ヒドロコルチゾンtxt
# 612
# ステロイドパルスtxt
# 6073
# 降圧薬txt
# 2973
# ミノサイクリンtxt
# 5826
# シスプラチンtxt
# 2540
# ステロイド剤txt
# 4034
# 利尿薬txt
# 1257
# メトトレキサートtxt
# 4073
# シクロフォスファミドtxt
# 1549
# アスピリンtxt
# 4679
# デキサメサゾンtxt
# 6895
# イマチニブtxt
# 364
# シクロホスファミドtxt
# 220
# 抗菌剤txt
# 5963
# 降圧剤txt
# 5362
# メサラジンtxt
# 5351
# トルバプタンtxt
# 3175
# アミオダロンtxt
# 1959
# コルチゾールtxt
# 2116
# 抗血小板薬txt
# 3134
# カテコラミンtxt
# 1037
# 抗菌薬txt
# 2159
# インスリンtxt
# 4073
# シクロスポリンtxt
# 4405
# セフトリアキソンtxt
# 5748
# メトホルミンtxt
# 5014
# アルガトロバンtxt
# 4562
# 抗生剤txt
# 7130
# ガンシクロビルtxt
# 458
# ステロイドtxt
# 5167
# チアマゾールtxt
# 215
# 抗生物質txt
# 5217
# アシクロビルtxt
# 737
# 利尿剤txt
# 4983
# アザチオプリンtxt
# 2932
# プレドニゾロンtxt
# 5788
# タクロリムスtxt
# 5601
# メトロニダゾールtxt
# 1730
# 造影剤txt
# 6131
# アルブミンtxt
# 1030
# フロセミドtxt
# 3458
# ウロキナーゼtxt
# 3451
# メチルプレドニゾロンtxt
# 7527
# 抗凝固薬txt
# ...
